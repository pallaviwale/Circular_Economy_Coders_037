# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_a=pd.read_csv("olist_sellers_dataset.csv")
df_a
# Out:
#                              seller_id  seller_zip_code_prefix  \
# 0     3442f8959a84dea7ee197c632cb2df15                   13023
# 1     d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2     ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3     c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4     51a04a8a6bdcb23deccc82b0b80742cf                   12914
# ...                                ...                     ...
# 3090  98dddbc4601dd4443ca174359b237166                   87111
# 3091  f8201cab383e484733266d1906e2fdfa                   88137
# 3092  74871d19219c7d518d0090283e03c137                    4650
# 3093  e603cf3fec55f8697c9059638d6c8eb5                   96080
# 3094  9e25199f6ef7e7c347120ff175652c3b                   12051
#
#             seller_city seller_state
# 0              campinas           SP
# 1            mogi guacu           SP
# 2        rio de janeiro           RJ
# 3             sao paulo           SP
# ...

# %%
df_b=pd.read_csv("product_category_name_translation.csv")
df_b
# Out:
#             product_category_name product_category_name_english
# 0                    beleza_saude                 health_beauty
# 1          informatica_acessorios         computers_accessories
# 2                      automotivo                          auto
# 3                 cama_mesa_banho                bed_bath_table
# 4                moveis_decoracao               furniture_decor
# ..                            ...                           ...
# 66                         flores                       flowers
# 67             artes_e_artesanato         arts_and_craftmanship
# 68                fraldas_higiene           diapers_and_hygiene
# 69  fashion_roupa_infanto_juvenil     fashion_childrens_clothes
# 70             seguros_e_servicos         security_and_services
#
# [71 rows x 2 columns]

# %%
df_a.isnull().sum(),df_b.isnull().sum()
# Out:
# (seller_id                 0
#  seller_zip_code_prefix    0
#  seller_city               0
#  seller_state              0
#  dtype: int64,
#  product_category_name            0
#  product_category_name_english    0
#  dtype: int64)

# %%
df_a.duplicated().sum() & df_b.duplicated().sum()
# Out:
# 0

# %%
city_count=df_a.groupby("seller_state")["seller_city"].nunique()

# %%
city_count
# Out:
# seller_state
# AC      1
# AM      1
# BA     12
# CE      7
# DF      3
# ES     11
# GO     12
# MA      1
# MG     82
# MS      2
# MT      3
# PA      1
# PB      5
# PE      4
# PI      1
# PR     67
# RJ     38
# RN      4
# RO      2
# RS     51
# SC     65
# SE      2
# SP    261
# Name: seller_city, dtype: int64

# %%
city_count_df = city_count_df.sort_values(by='CityCount', ascending=False.reset_index())
city_count_df
# Out:
#    seller_state  CityCount
# 22           SP        261
# 8            MG         82
# 15           PR         67
# 20           SC         65
# 19           RS         51
# 16           RJ         38
# 6            GO         12
# 2            BA         12
# 5            ES         11
# 3            CE          7
# 12           PB          5
# 13           PE          4
# 17           RN          4
# 10           MT          3
# 4            DF          3
# 9            MS          2
# 21           SE          2
# 18           RO          2
# 14           PI          1
# 1            AM          1
# 11           PA          1
# 7            MA          1
# 0            AC          1

# %%
sns.barplot(data=city_count_df, x='seller_state', y='CityCount')
plt.show()
